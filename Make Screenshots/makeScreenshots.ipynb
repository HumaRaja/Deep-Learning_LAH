# %%
# !pip install pillow
# !pip install keyboard

## Not installed
# pip install pydirectinput
# pip install opencv-python
# pip install tensorflow
# pip install pillow
# pip install keras

# %%
from PIL import ImageGrab
import keyboard
import os

# Define the base folder where screenshots will be saved
save_folder = "Screenshots"
os.makedirs(save_folder, exist_ok=True)  # Create the base folder if it doesn't exist

# Define the keys you're interested in for classification
keys_of_interest = ['d', 'z', 'q']

# Define the region of interest (coordinates - left, top, right, bottom)
region = (0, 600, 1920, 900)  # Replace with your desired coordinates

# Function to take a screenshot and save it in the corresponding folder
def take_screenshot(key):
  # Check if the key is one of the keys we want to classify
  if key not in keys_of_interest:
    return

  # Create a subfolder for the key press if it doesn't exist
  key_folder = os.path.join(save_folder, key)
  os.makedirs(key_folder, exist_ok=True)

  # Capture the screenshot of the specific region
  screenshot = ImageGrab.grab(region)

  # Get the screenshot count for this key
  screenshot_count = len(os.listdir(key_folder)) + 1

  # Save the screenshot in the corresponding subfolder with a numbered filename
  screenshot_filename = os.path.join(key_folder, f"{key}{screenshot_count}.png")
  screenshot.save(screenshot_filename)

  # Close the screenshot object
  screenshot.close()

  print(f"Screenshot saved as: {screenshot_filename} in folder: {key}")

# Function to handle key press events
def on_key_release(event):
  key = event.name  # Get the key that was released

  print(f"Key released: {key}")

  # Stop the program if the alt key is pressed
  if key == "alt":
    print("Alt key pressed. Exiting the program safely...")
    keyboard.unhook_all()  # Stop listening for key presses
  else:
    # Only take screenshots for 'z', 'q', or 'd'
    take_screenshot(key)

# Hook the keyboard to detect key releases
keyboard.on_release(on_key_release)

# The program runs indefinitely to listen for key releases
keyboard.wait()
# Out:
# Key released: z
# Screenshot saved as: Screenshots\z\z1.png in folder: z
# Key released: z
# Screenshot saved as: Screenshots\z\z2.png in folder: z
# Key released: z
# Screenshot saved as: Screenshots\z\z3.png in folder: z
# Key released: z
# Screenshot saved as: Screenshots\z\z4.png in folder: z
# Key released: z
# Screenshot saved as: Screenshots\z\z5.png in folder: z
# Key released: z
# Screenshot saved as: Screenshots\z\z6.png in folder: z
# Key released: d
# Screenshot saved as: Screenshots\d\d1.png in folder: d
# Key released: d
# Screenshot saved as: Screenshots\d\d2.png in folder: d
# Key released: d
# Screenshot saved as: Screenshots\d\d3.png in folder: d
# Key released: d
# Screenshot saved as: Screenshots\d\d4.png in folder: d
# Key released: d
# Screenshot saved as: Screenshots\d\d5.png in folder: d
# Key released: d
# Screenshot saved as: Screenshots\d\d6.png in folder: d
# Key released: z
# Screenshot saved as: Screenshots\z\z7.png in folder: z
# Key released: q
# Screenshot saved as: Screenshots\q\q1.png in folder: q
# Key released: z
# Screenshot saved as: Screenshots\z\z8.png in folder: z
# Key released: q
# Screenshot saved as: Screenshots\q\q2.png in folder: q
# Key released: q
# Screenshot saved as: Screenshots\q\q3.png in folder: q
# Key released: q
# Screenshot saved as: Screenshots\q\q4.png in folder: q
# Key released: z
# Screenshot saved as: Screenshots\z\z9.png in folder: z
# Key released: d
# Screenshot saved as: Screenshots\d\d7.png in folder: d
# Key released: z
# Screenshot saved as: Screenshots\z\z10.png in folder: z
# Key released: d
# Screenshot saved as: Screenshots\d\d8.png in folder: d
# Key released: d
# Screenshot saved as: Screenshots\d\d9.png in folder: d
# Key released: d
# Screenshot saved as: Screenshots\d\d10.png in folder: d
# Key released: d
# Screenshot saved as: Screenshots\d\d11.png in folder: d
# Key released: z
# Screenshot saved as: Screenshots\z\z11.png in folder: z
# Key released: tab
# Key released: alt
# Alt key pressed. Exiting the program safely...
